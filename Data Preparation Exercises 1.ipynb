# %% [markdown]
# #### Execute the following in Jupyter notebook. Each question carries 2 marks.
#
# Q1)  Read data from https://vincentarelbundock.github.io/Rdatasets/csv/Stat2Data/NCbirths.csv
#
# Q2)  Print the shape of the data
#
# Q3)  Print columns that contain null values with the number of null values in each.
#
# Q4)  Print the row(s) that contain maximum number of NA values
#
# Q5)  Print the count of male and female babies
#
# Q6)  Print the percentage of missing values in each column
#
# Q7)  How many columns are dropped if we decide to eliminate columns that contain more than 1% of null values?
#
# Q8)  How many rows are dropped if we decide to eliminate rows that contain more than 5% of null values?
#
# Q9)  Print the dataframe by filling NA values with the mean of the column
#
# Q10) Print the dataframe using the back fill method

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Q1) Read data from https://vincentarelbundock.github.io/Rdatasets/csv/Stat2Data/NCbirths.csv**

# %%
df = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/Stat2Data/NCbirths.csv")

# %%
df
# Out:
#       Unnamed: 0    ID  Plural  Sex  MomAge  Weeks  Marital  RaceMom HispMom  \
# 0              1     1       1    1      32   40.0        1        1       N
# 1              2     2       1    2      32   37.0        1        1       N
# 2              3     3       1    1      27   39.0        1        1       N
# 3              4     4       1    1      27   39.0        1        1       N
# 4              5     5       1    1      25   39.0        1        1       N
# ...          ...   ...     ...  ...     ...    ...      ...      ...     ...
# 1445        1446  1446       1    2      24   45.0        1        8       N
# 1446        1447  1447       1    2      32   38.0        1        8       N
# 1447        1448  1448       1    2      32   40.0        1        8       N
# 1448        1449  1449       1    1      30   32.0        1        8       N
# 1449        1450  1450       1    2      40   42.0        1        8       N
#
#       Gained  Smoke  BirthWeightOz  BirthWeightGm  Low  Premie MomRace
# 0       38.0    0.0            111        3146.85    0       0   white
# 1       34.0    0.0            116        3288.60    0       0   white
# 2       12.0    0.0            138        3912.30    0       0   white
# 3       15.0    0.0            136        3855.60    0       0   white
# 4       32.0    0.0            121        3430.35    0       0   white
# ...      ...    ...            ...            ...  ...     ...     ...
# 1445    55.0    0.0            133        3770.55    0       0   other
# 1446    35.0    0.0             95        2693.25    0       0   other
# 1447    29.0    0.0            123        3487.05    0       0   other
# 1448    30.0    0.0             70        1984.50    1       1   other
# 1449    32.0    0.0            120        3402.00    0       0   other
#
# [1450 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 16 columns):
# Unnamed: 0       1450 non-null int64
# ID               1450 non-null int64
# Plural           1450 non-null int64
# Sex              1450 non-null int64
# MomAge           1450 non-null int64
# Weeks            1449 non-null float64
# Marital          1450 non-null int64
# RaceMom          1450 non-null int64
# HispMom          1450 non-null object
# Gained           1410 non-null float64
# Smoke            1445 non-null float64
# BirthWeightOz    1450 non-null int64
# BirthWeightGm    1450 non-null float64
# Low              1450 non-null int64
# Premie           1450 non-null int64
# MomRace          1450 non-null object
# dtypes: float64(4), int64(10), object(2)
# memory usage: 181.4+ KB

# %%
df.head()
# Out:
#    Unnamed: 0  ID  Plural  Sex  MomAge  Weeks  Marital  RaceMom HispMom  \
# 0           1   1       1    1      32   40.0        1        1       N
# 1           2   2       1    2      32   37.0        1        1       N
# 2           3   3       1    1      27   39.0        1        1       N
# 3           4   4       1    1      27   39.0        1        1       N
# 4           5   5       1    1      25   39.0        1        1       N
#
#    Gained  Smoke  BirthWeightOz  BirthWeightGm  Low  Premie MomRace
# 0    38.0    0.0            111        3146.85    0       0   white
# 1    34.0    0.0            116        3288.60    0       0   white
# 2    12.0    0.0            138        3912.30    0       0   white
# 3    15.0    0.0            136        3855.60    0       0   white
# 4    32.0    0.0            121        3430.35    0       0   white

# %%
df.tail()
# Out:
#       Unnamed: 0    ID  Plural  Sex  MomAge  Weeks  Marital  RaceMom HispMom  \
# 1445        1446  1446       1    2      24   45.0        1        8       N
# 1446        1447  1447       1    2      32   38.0        1        8       N
# 1447        1448  1448       1    2      32   40.0        1        8       N
# 1448        1449  1449       1    1      30   32.0        1        8       N
# 1449        1450  1450       1    2      40   42.0        1        8       N
#
#       Gained  Smoke  BirthWeightOz  BirthWeightGm  Low  Premie MomRace
# 1445    55.0    0.0            133        3770.55    0       0   other
# 1446    35.0    0.0             95        2693.25    0       0   other
# 1447    29.0    0.0            123        3487.05    0       0   other
# 1448    30.0    0.0             70        1984.50    1       1   other
# 1449    32.0    0.0            120        3402.00    0       0   other

# %% [markdown]
# **Q2) Print the shape of the data**

# %%
df.shape #shape of data
# Out:
# (1450, 16)

# %% [markdown]
# **Q3) Print columns that contain null values with the number of null values in each**

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# ID                0
# Plural            0
# Sex               0
# MomAge            0
# Weeks             1
# Marital           0
# RaceMom           0
# HispMom           0
# Gained           40
# Smoke             5
# BirthWeightOz     0
# BirthWeightGm     0
# Low               0
# Premie            0
# MomRace           0
# dtype: int64

# %% [markdown]
# **Q4) Print the row(s) that contain maximum number of NA values.**

# %%
df[df.isnull().sum(axis=1)==df.isnull().sum(axis=1).max()]
# Out:
#       Unnamed: 0    ID  Plural  Sex  MomAge  Weeks  Marital  RaceMom HispMom  \
# 247          248   248       1    1      37   37.0        1        1       N
# 797          798   798       1    1      31   38.0        1        1       N
# 994          995   995       1    1      20   42.0        2        1       N
# 1117        1118  1118       1    1      20    NaN        2        2       N
# 1206        1207  1207       1    1      20   37.0        1        2       N
#
#       Gained  Smoke  BirthWeightOz  BirthWeightGm  Low  Premie MomRace
# 247      NaN    NaN            102         2891.7    0       0   white
# 797      NaN    NaN            130         3685.5    0       0   white
# 994      NaN    NaN             96         2721.6    0       0   white
# 1117     NaN    0.0            136         3855.6    0       1   black
# 1206     NaN    NaN             94         2664.9    0       0   black

# %% [markdown]
# **Q5) Print the count of male and female babies**

# %%
df.head(5)
# Out:
#    Unnamed: 0  ID  Plural  Sex  MomAge  Weeks  Marital  RaceMom HispMom  \
# 0           1   1       1    1      32   40.0        1        1       N
# 1           2   2       1    2      32   37.0        1        1       N
# 2           3   3       1    1      27   39.0        1        1       N
# 3           4   4       1    1      27   39.0        1        1       N
# 4           5   5       1    1      25   39.0        1        1       N
#
#    Gained  Smoke  BirthWeightOz  BirthWeightGm  Low  Premie MomRace
# 0    38.0    0.0            111        3146.85    0       0   white
# 1    34.0    0.0            116        3288.60    0       0   white
# 2    12.0    0.0            138        3912.30    0       0   white
# 3    15.0    0.0            136        3855.60    0       0   white
# 4    32.0    0.0            121        3430.35    0       0   white

# %%
print(sum(df['Sex']))
# Out:
# 2156

# %%
males = [i for i in df['Sex'] if i==1]
print(sum(males))
# Out:
# 744

# %%
females = [i for i in df['Sex'] if i==2]
print(sum(females))
# Out:
# 1412

# %% [markdown]
# **Q6) Print the percentage of missing values in each column**

# %%
missing_count=df.isnull().sum()
(missing_count/np.product(df.shape))*100
# Out:
# Unnamed: 0       0.000000
# ID               0.000000
# Plural           0.000000
# Sex              0.000000
# MomAge           0.000000
# Weeks            0.004310
# Marital          0.000000
# RaceMom          0.000000
# HispMom          0.000000
# Gained           0.172414
# Smoke            0.021552
# BirthWeightOz    0.000000
# BirthWeightGm    0.000000
# Low              0.000000
# Premie           0.000000
# MomRace          0.000000
# dtype: float64

# %%
df.shape
# Out:
# (1450, 16)

# %% [markdown]
# **Q7) How many columns are dropped if we decide to eliminate columns that contain more than 1% of null values?**

# %%
df.dropna(axis=1, thresh=1435)
# Out:
#       Unnamed: 0    ID  Plural  Sex  MomAge  Weeks  Marital  RaceMom HispMom  \
# 0              1     1       1    1      32   40.0        1        1       N
# 1              2     2       1    2      32   37.0        1        1       N
# 2              3     3       1    1      27   39.0        1        1       N
# 3              4     4       1    1      27   39.0        1        1       N
# 4              5     5       1    1      25   39.0        1        1       N
# ...          ...   ...     ...  ...     ...    ...      ...      ...     ...
# 1445        1446  1446       1    2      24   45.0        1        8       N
# 1446        1447  1447       1    2      32   38.0        1        8       N
# 1447        1448  1448       1    2      32   40.0        1        8       N
# 1448        1449  1449       1    1      30   32.0        1        8       N
# 1449        1450  1450       1    2      40   42.0        1        8       N
#
#       Smoke  BirthWeightOz  BirthWeightGm  Low  Premie MomRace
# 0       0.0            111        3146.85    0       0   white
# 1       0.0            116        3288.60    0       0   white
# 2       0.0            138        3912.30    0       0   white
# 3       0.0            136        3855.60    0       0   white
# 4       0.0            121        3430.35    0       0   white
# ...     ...            ...            ...  ...     ...     ...
# 1445    0.0            133        3770.55    0       0   other
# 1446    0.0             95        2693.25    0       0   other
# 1447    0.0            123        3487.05    0       0   other
# 1448    0.0             70        1984.50    1       1   other
# 1449    0.0            120        3402.00    0       0   other
#
# [1450 rows x 15 columns]

# %% [markdown]
# 1 column out of the 16 column gets dropped if we drop 1% of the null values.

# %% [markdown]
# **Q8) How many rows are dropped if we decide to eliminate rows that contain more than 5% of null values?**

# %%
df.dropna(thresh=15)
# Out:
#       Unnamed: 0    ID  Plural  Sex  MomAge  Weeks  Marital  RaceMom HispMom  \
# 0              1     1       1    1      32   40.0        1        1       N
# 1              2     2       1    2      32   37.0        1        1       N
# 2              3     3       1    1      27   39.0        1        1       N
# 3              4     4       1    1      27   39.0        1        1       N
# 4              5     5       1    1      25   39.0        1        1       N
# ...          ...   ...     ...  ...     ...    ...      ...      ...     ...
# 1445        1446  1446       1    2      24   45.0        1        8       N
# 1446        1447  1447       1    2      32   38.0        1        8       N
# 1447        1448  1448       1    2      32   40.0        1        8       N
# 1448        1449  1449       1    1      30   32.0        1        8       N
# 1449        1450  1450       1    2      40   42.0        1        8       N
#
#       Gained  Smoke  BirthWeightOz  BirthWeightGm  Low  Premie MomRace
# 0       38.0    0.0            111        3146.85    0       0   white
# 1       34.0    0.0            116        3288.60    0       0   white
# 2       12.0    0.0            138        3912.30    0       0   white
# 3       15.0    0.0            136        3855.60    0       0   white
# 4       32.0    0.0            121        3430.35    0       0   white
# ...      ...    ...            ...            ...  ...     ...     ...
# 1445    55.0    0.0            133        3770.55    0       0   other
# 1446    35.0    0.0             95        2693.25    0       0   other
# 1447    29.0    0.0            123        3487.05    0       0   other
# 1448    30.0    0.0             70        1984.50    1       1   other
# 1449    32.0    0.0            120        3402.00    0       0   other
#
# [1445 rows x 16 columns]

# %% [markdown]
# 5 rows get dropped if we decide to drop 5% of null values.

# %% [markdown]
# **Q9) Print the dataframe by filling NA values with the mean of the column**

# %%
df.fillna(df.mean(axis=1))
# Out:
#       Unnamed: 0    ID  Plural  Sex  MomAge  Weeks  Marital  RaceMom HispMom  \
# 0              1     1       1    1      32   40.0        1        1       N
# 1              2     2       1    2      32   37.0        1        1       N
# 2              3     3       1    1      27   39.0        1        1       N
# 3              4     4       1    1      27   39.0        1        1       N
# 4              5     5       1    1      25   39.0        1        1       N
# ...          ...   ...     ...  ...     ...    ...      ...      ...     ...
# 1445        1446  1446       1    2      24   45.0        1        8       N
# 1446        1447  1447       1    2      32   38.0        1        8       N
# 1447        1448  1448       1    2      32   40.0        1        8       N
# 1448        1449  1449       1    1      30   32.0        1        8       N
# 1449        1450  1450       1    2      40   42.0        1        8       N
#
#       Gained  Smoke  BirthWeightOz  BirthWeightGm  Low  Premie MomRace
# 0       38.0    0.0            111        3146.85    0       0   white
# 1       34.0    0.0            116        3288.60    0       0   white
# 2       12.0    0.0            138        3912.30    0       0   white
# 3       15.0    0.0            136        3855.60    0       0   white
# 4       32.0    0.0            121        3430.35    0       0   white
# ...      ...    ...            ...            ...  ...     ...     ...
# 1445    55.0    0.0            133        3770.55    0       0   other
# 1446    35.0    0.0             95        2693.25    0       0   other
# 1447    29.0    0.0            123        3487.05    0       0   other
# 1448    30.0    0.0             70        1984.50    1       1   other
# 1449    32.0    0.0            120        3402.00    0       0   other
#
# [1450 rows x 16 columns]

# %% [markdown]
# **Q10) Print the dataframe using the back fill method**

# %%
df.fillna(method='bfill')
# Out:
#       Unnamed: 0    ID  Plural  Sex  MomAge  Weeks  Marital  RaceMom HispMom  \
# 0              1     1       1    1      32   40.0        1        1       N
# 1              2     2       1    2      32   37.0        1        1       N
# 2              3     3       1    1      27   39.0        1        1       N
# 3              4     4       1    1      27   39.0        1        1       N
# 4              5     5       1    1      25   39.0        1        1       N
# ...          ...   ...     ...  ...     ...    ...      ...      ...     ...
# 1445        1446  1446       1    2      24   45.0        1        8       N
# 1446        1447  1447       1    2      32   38.0        1        8       N
# 1447        1448  1448       1    2      32   40.0        1        8       N
# 1448        1449  1449       1    1      30   32.0        1        8       N
# 1449        1450  1450       1    2      40   42.0        1        8       N
#
#       Gained  Smoke  BirthWeightOz  BirthWeightGm  Low  Premie MomRace
# 0       38.0    0.0            111        3146.85    0       0   white
# 1       34.0    0.0            116        3288.60    0       0   white
# 2       12.0    0.0            138        3912.30    0       0   white
# 3       15.0    0.0            136        3855.60    0       0   white
# 4       32.0    0.0            121        3430.35    0       0   white
# ...      ...    ...            ...            ...  ...     ...     ...
# 1445    55.0    0.0            133        3770.55    0       0   other
# 1446    35.0    0.0             95        2693.25    0       0   other
# 1447    29.0    0.0            123        3487.05    0       0   other
# 1448    30.0    0.0             70        1984.50    1       1   other
# 1449    32.0    0.0            120        3402.00    0       0   other
#
# [1450 rows x 16 columns]
